# %% [markdown]
# Taken from: https://www.kaggle.com/adityadesai13/used-car-dataset-ford-and-mercedes

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install scikit-optimize
# Out:
# ...
#      |████████████████████████████████| 102kB 4.2MB/s
# ...

# %%
import pandas as pd
import sys
sys.path.insert(0,'/content/drive/My Drive/Datasets_SVR/Library')
from subsamplesvr import svr_subsample_bayes_train
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_absolute_error, mean_squared_error
from sklearn.svm import SVR
import numpy as np
import time
import math
from sklearn.preprocessing import StandardScaler
from skopt import BayesSearchCV

# %%
audi_data=pd.read_csv("/content/drive/My Drive/Datasets_SVR/Data/Used Cars Datasets/audi.csv")
bmw_data=pd.read_csv("/content/drive/My Drive/Datasets_SVR/Data/Used Cars Datasets/bmw.csv")
ford_data=pd.read_csv("/content/drive/My Drive/Datasets_SVR/Data/Used Cars Datasets/ford.csv")
hyundi_data=pd.read_csv("/content/drive/My Drive/Datasets_SVR/Data/Used Cars Datasets/hyundi.csv")
merc_data=pd.read_csv("/content/drive/My Drive/Datasets_SVR/Data/Used Cars Datasets/merc.csv")
skoda_data=pd.read_csv("/content/drive/My Drive/Datasets_SVR/Data/Used Cars Datasets/skoda.csv")
toyota_data=pd.read_csv("/content/drive/My Drive/Datasets_SVR/Data/Used Cars Datasets/toyota.csv")
vauxhall_data=pd.read_csv("/content/drive/My Drive/Datasets_SVR/Data/Used Cars Datasets/vauxhall.csv")
vw_data=pd.read_csv("/content/drive/My Drive/Datasets_SVR/Data/Used Cars Datasets/vw.csv")

# %%
print(audi_data.info())
display(audi_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10668 entries, 0 to 10667
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10668 non-null  object
#  1   year          10668 non-null  int64
#  2   price         10668 non-null  int64
#  3   transmission  10668 non-null  object
#  4   mileage       10668 non-null  int64
#  5   fuelType      10668 non-null  object
#  6   tax           10668 non-null  int64
#  7   mpg           10668 non-null  float64
#  8   engineSize    10668 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 750.2+ KB
# None
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# ...

# %%
print(bmw_data.info())
display(bmw_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  object
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  object
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10781 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 758.2+ KB
# None
#        model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6         2.0
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8         2.0
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4         3.0
# ...

# %%
print(ford_data.info())
display(ford_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17965 entries, 0 to 17964
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         17965 non-null  object
#  1   year          17965 non-null  int64
#  2   price         17965 non-null  int64
#  3   transmission  17965 non-null  object
#  4   mileage       17965 non-null  int64
#  5   fuelType      17965 non-null  object
#  6   tax           17965 non-null  int64
#  7   mpg           17965 non-null  float64
#  8   engineSize    17965 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 1.2+ MB
# None
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# ...

# %%
print(hyundi_data.info())
display(hyundi_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4860 entries, 0 to 4859
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         4860 non-null   object
#  1   year          4860 non-null   int64
#  2   price         4860 non-null   int64
#  3   transmission  4860 non-null   object
#  4   mileage       4860 non-null   int64
#  5   fuelType      4860 non-null   object
#  6   tax(£)        4860 non-null   int64
#  7   mpg           4860 non-null   float64
#  8   engineSize    4860 non-null   float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 341.8+ KB
# None
#      model  year  price transmission  ...  fuelType tax(£)   mpg  engineSize
# 0      I20  2017   7999       Manual  ...    Petrol    145  58.9         1.2
# 1   Tucson  2016  14499    Automatic  ...    Diesel    235  43.5         2.0
# 2   Tucson  2016  11399       Manual  ...    Diesel     30  61.7         1.7
# ...

# %%
hyundi_data.rename(columns={'tax(£)':'tax'}, inplace=True)
hyundi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4860 entries, 0 to 4859
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         4860 non-null   object
#  1   year          4860 non-null   int64
#  2   price         4860 non-null   int64
#  3   transmission  4860 non-null   object
#  4   mileage       4860 non-null   int64
#  5   fuelType      4860 non-null   object
#  6   tax           4860 non-null   int64
#  7   mpg           4860 non-null   float64
#  8   engineSize    4860 non-null   float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 341.8+ KB

# %%
print(merc_data.info())
display(merc_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13119 entries, 0 to 13118
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         13119 non-null  object
#  1   year          13119 non-null  int64
#  2   price         13119 non-null  int64
#  3   transmission  13119 non-null  object
#  4   mileage       13119 non-null  int64
#  5   fuelType      13119 non-null  object
#  6   tax           13119 non-null  int64
#  7   mpg           13119 non-null  float64
#  8   engineSize    13119 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 922.6+ KB
# None
#        model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1         1.8
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4         2.1
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0         5.5
# ...

# %%
print(skoda_data.info())
display(skoda_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6267 entries, 0 to 6266
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         6267 non-null   object
#  1   year          6267 non-null   int64
#  2   price         6267 non-null   int64
#  3   transmission  6267 non-null   object
#  4   mileage       6267 non-null   int64
#  5   fuelType      6267 non-null   object
#  6   tax           6267 non-null   int64
#  7   mpg           6267 non-null   float64
#  8   engineSize    6267 non-null   float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 440.8+ KB
# None
#            model  year  price transmission  ...  fuelType  tax   mpg  engineSize
# 0        Octavia  2017  10550       Manual  ...    Petrol  150  54.3         1.4
# 1         Citigo  2018   8200       Manual  ...    Petrol  145  67.3         1.0
# 2        Octavia  2019  15650    Automatic  ...    Diesel  145  67.3         2.0
# ...

# %%
print(toyota_data.info())
display(toyota_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6738 entries, 0 to 6737
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         6738 non-null   object
#  1   year          6738 non-null   int64
#  2   price         6738 non-null   int64
#  3   transmission  6738 non-null   object
#  4   mileage       6738 non-null   int64
#  5   fuelType      6738 non-null   object
#  6   tax           6738 non-null   int64
#  7   mpg           6738 non-null   float64
#  8   engineSize    6738 non-null   float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 473.9+ KB
# None
#    model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
# 1   GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0
# 2   GT86  2015  13998       Manual    27469   Petrol  265  36.2         2.0
# ...

# %%
print(vauxhall_data.info())
display(vauxhall_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13632 entries, 0 to 13631
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         13632 non-null  object
#  1   year          13632 non-null  int64
#  2   price         13632 non-null  int64
#  3   transmission  13632 non-null  object
#  4   mileage       13632 non-null  int64
#  5   fuelType      13632 non-null  object
#  6   tax           13632 non-null  int64
#  7   mpg           13632 non-null  float64
#  8   engineSize    13632 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 958.6+ KB
# None
#     model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Corsa  2018   7885       Manual     9876   Petrol  145  55.4         1.4
# 1   Corsa  2019  11995       Manual     2500   Petrol  145  54.3         1.4
# 2   Corsa  2017   9777    Automatic     9625   Petrol  145  47.9         1.4
# ...

# %%
print(vw_data.info())
display(vw_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15157 entries, 0 to 15156
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         15157 non-null  object
#  1   year          15157 non-null  int64
#  2   price         15157 non-null  int64
#  3   transmission  15157 non-null  object
#  4   mileage       15157 non-null  int64
#  5   fuelType      15157 non-null  object
#  6   tax           15157 non-null  int64
#  7   mpg           15157 non-null  float64
#  8   engineSize    15157 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 1.0+ MB
# None
#     model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   T-Roc  2019  25000    Automatic    13904   Diesel  145  49.6         2.0
# 1   T-Roc  2019  26883    Automatic     4562   Diesel  145  49.6         2.0
# 2   T-Roc  2019  20000       Manual     7414   Diesel  145  50.4         2.0
# ...

# %%
audi_data['model'] = 'audi'
bmw_data['model'] = 'bmw'
ford_data['model'] = 'ford'
hyundi_data['model'] = 'hyundai'
merc_data['model'] = 'mercedez'
skoda_data['model'] = 'skoda'
toyota_data['model'] = 'toyota'
vauxhall_data['model'] = 'vauxhall'
vw_data['model'] = 'vw'

# %%
used_cars=pd.concat([audi_data,bmw_data,ford_data,hyundi_data,merc_data,skoda_data,toyota_data,vauxhall_data,vw_data])

# %%
used_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99187 entries, 0 to 15156
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         99187 non-null  object
#  1   year          99187 non-null  int64
#  2   price         99187 non-null  int64
#  3   transmission  99187 non-null  object
#  4   mileage       99187 non-null  int64
#  5   fuelType      99187 non-null  object
#  6   tax           99187 non-null  int64
#  7   mpg           99187 non-null  float64
#  8   engineSize    99187 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 7.6+ MB

# %%
used_cars['model'].value_counts()
# Out:
# ford        17965
# vw          15157
# vauxhall    13632
# mercedez    13119
# bmw         10781
# audi        10668
# toyota       6738
# skoda        6267
# hyundai      4860
# Name: model, dtype: int64

# %%
used_cars['year'].value_counts()
# Out:
# 2019    26771
# 2017    21733
# 2016    15850
# 2018    13664
# 2015     7645
# 2020     4465
# 2014     4085
# 2013     2603
# 2012      634
# 2011      432
# 2010      340
# 2009      278
# 2008      200
# 2007      163
# 2006       86
# 2005       69
# 2004       52
# 2003       34
# 2002       31
# 2001       20
# 2000        9
# 1998        8
# 1999        6
# 1997        4
# 1970        2
# 1996        2
# 2060        1
# Name: year, dtype: int64

# %%
used_cars['transmission'].value_counts()
# Out:
# Manual       56445
# Semi-Auto    22677
# Automatic    20056
# Other            9
# Name: transmission, dtype: int64

# %%
used_cars['fuelType'].value_counts()
# Out:
# Petrol      54928
# Diesel      40928
# Hybrid       3078
# Other         247
# Electric        6
# Name: fuelType, dtype: int64

# %%
used_cars.describe().T
# Out:
#               count          mean           std  ...      50%      75%       max
# year        99187.0   2017.087723      2.123934  ...   2017.0   2019.0    2060.0
# price       99187.0  16805.347656   9866.773417  ...  14495.0  20870.0  159999.0
# mileage     99187.0  23058.914213  21148.523721  ...  17460.0  32339.0  323000.0
# tax         99187.0    120.299838     63.150926  ...    145.0    145.0     580.0
# mpg         99187.0     55.166825     16.138522  ...     54.3     62.8     470.8
# engineSize  99187.0      1.663280      0.557646  ...      1.6      2.0       6.6
#
# [6 rows x 8 columns]

# %%
used_cars = used_cars[used_cars['year'] <= 2021]

# %%
used_cars.describe().T
# Out:
#               count          mean           std  ...      50%       75%       max
# year        99186.0   2017.087291      2.119570  ...   2017.0   2019.00    2020.0
# price       99186.0  16805.451606   9866.768844  ...  14495.0  20870.00  159999.0
# mileage     99186.0  23058.594126  21148.390071  ...  17460.0  32337.75  323000.0
# tax         99186.0    120.298984     63.150672  ...    145.0    145.00     580.0
# mpg         99186.0     55.166950     16.138556  ...     54.3     62.80     470.8
# engineSize  99186.0      1.663283      0.557649  ...      1.6      2.00       6.6
#
# [6 rows x 8 columns]

# %%
used_cars.isna().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
print(used_cars.shape)
# Out:
# (99186, 9)

# %%
used_cars
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0      audi  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1      audi  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2      audi  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3      audi  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4      audi  2019  17300       Manual     1998   Petrol  145  49.6         1.0
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 15152    vw  2012   5990       Manual    74000   Diesel  125  58.9         2.0
# 15153    vw  2008   1799       Manual    88102   Petrol  145  46.3         1.2
# 15154    vw  2009   1590       Manual    70000   Petrol  200  42.0         1.4
# 15155    vw  2006   1250       Manual    82704   Petrol  150  46.3         1.2
# 15156    vw  2007   2295       Manual    74000   Petrol  145  46.3         1.2
#
# ...

# %%
used_cars.isna().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
used_cars['transmission'].replace(to_replace=['Manual'],value=0,inplace=True)
used_cars['transmission'].replace(to_replace=['Semi-Auto'],value=1,inplace=True)
used_cars['transmission'].replace(to_replace=['Automatic'],value=2,inplace=True)
used_cars['transmission'].replace(to_replace=['Other'],value=3,inplace=True)

# %%
used_cars['fuelType'].replace(to_replace=['Petrol'],value=10,inplace=True)
used_cars['fuelType'].replace(to_replace=['Diesel'],value=9,inplace=True)
used_cars['fuelType'].replace(to_replace=['Hybrid'],value=8,inplace=True)
used_cars['fuelType'].replace(to_replace=['Other'],value=7,inplace=True)
used_cars['fuelType'].replace(to_replace=['Electric'],value=6,inplace=True)

# %%
used_cars['model'].replace(to_replace=['ford'],value=30,inplace=True)
used_cars['model'].replace(to_replace=['vw'],value=29,inplace=True)
used_cars['model'].replace(to_replace=['vauxhall'],value=28,inplace=True)
used_cars['model'].replace(to_replace=['mercedez'],value=27,inplace=True)
used_cars['model'].replace(to_replace=['bmw'],value=26,inplace=True)
used_cars['model'].replace(to_replace=['audi'],value=25,inplace=True)
used_cars['model'].replace(to_replace=['toyota'],value=24,inplace=True)
used_cars['model'].replace(to_replace=['skoda'],value=23,inplace=True)
used_cars['model'].replace(to_replace=['hyundai'],value=22,inplace=True)

# %%
used_cars['transmission'].value_counts()
# Out:
# 0    56445
# 1    22677
# 2    20055
# 3        9
# Name: transmission, dtype: int64

# %%
used_cars['fuelType'].value_counts()
# Out:
# 10    54927
# 9     40928
# 8      3078
# 7       247
# 6         6
# Name: fuelType, dtype: int64

# %%
used_cars['model'].value_counts()
# Out:
# 30    17964
# 29    15157
# 28    13632
# 27    13119
# 26    10781
# 25    10668
# 24     6738
# 23     6267
# 22     4860
# Name: model, dtype: int64

# %%
used_cars
# Out:
#        model  year  price  transmission  ...  fuelType  tax   mpg  engineSize
# 0         25  2017  12500             0  ...        10  150  55.4         1.4
# 1         25  2016  16500             2  ...         9   20  64.2         2.0
# 2         25  2016  11000             0  ...        10   30  55.4         1.4
# 3         25  2017  16800             2  ...         9  145  67.3         2.0
# 4         25  2019  17300             0  ...        10  145  49.6         1.0
# ...      ...   ...    ...           ...  ...       ...  ...   ...         ...
# 15152     29  2012   5990             0  ...         9  125  58.9         2.0
# 15153     29  2008   1799             0  ...        10  145  46.3         1.2
# 15154     29  2009   1590             0  ...        10  200  42.0         1.4
# 15155     29  2006   1250             0  ...        10  150  46.3         1.2
# 15156     29  2007   2295             0  ...        10  145  46.3         1.2
#
# [99186 rows x 9 columns]

# %%
used_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99186 entries, 0 to 15156
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         99186 non-null  int64
#  1   year          99186 non-null  int64
#  2   price         99186 non-null  int64
#  3   transmission  99186 non-null  int64
#  4   mileage       99186 non-null  int64
#  5   fuelType      99186 non-null  int64
#  6   tax           99186 non-null  int64
#  7   mpg           99186 non-null  float64
#  8   engineSize    99186 non-null  float64
# dtypes: float64(2), int64(7)
# memory usage: 7.6 MB

# %%
used_cars.describe().T
# Out:
#                 count          mean           std  ...      50%       75%       max
# model         99186.0     26.961073      2.400729  ...     27.0     29.00      30.0
# year          99186.0   2017.087291      2.119570  ...   2017.0   2019.00    2020.0
# price         99186.0  16805.451606   9866.768844  ...  14495.0  20870.00  159999.0
# transmission  99186.0      0.633295      0.798232  ...      0.0      1.00       3.0
# mileage       99186.0  23058.594126  21148.390071  ...  17460.0  32337.75  323000.0
# fuelType      99186.0      9.517583      0.572212  ...     10.0     10.00      10.0
# tax           99186.0    120.298984     63.150672  ...    145.0    145.00     580.0
# mpg           99186.0     55.166950     16.138556  ...     54.3     62.80     470.8
# engineSize    99186.0      1.663283      0.557649  ...      1.6      2.00       6.6
#
# [9 rows x 8 columns]

# %%
x_train,x_test=train_test_split(used_cars,test_size=0.20)

# %%
x_train
# Out:
#        model  year  price  transmission  ...  fuelType  tax   mpg  engineSize
# 6089      26  2014  20572             1  ...         9  145  54.3         2.0
# 9696      30  2018  14990             0  ...        10  145  53.3         1.0
# 8769      29  2017   9950             0  ...        10  150  60.1         1.2
# 11240     30  2019  18999             0  ...        10  145  34.4         1.5
# 3721      28  2013   4798             0  ...        10  160  44.8         1.6
# ...      ...   ...    ...           ...  ...       ...  ...   ...         ...
# 8464      29  2017   9990             0  ...        10  145  60.1         1.2
# 786       28  2016   7955             0  ...        10   30  54.3         1.4
# 9760      30  2016   9990             0  ...        10  145  47.9         1.6
# 2021      23  2017   8350             0  ...        10  150  60.1         1.2
# 5999      30  2018  16790             0  ...        10  145  45.6         1.5
#
# [79348 rows x 9 columns]

# %%
x_test
# Out:
#        model  year  price  transmission  ...  fuelType  tax   mpg  engineSize
# 1232      23  2020  19990             0  ...         9  145  54.3         1.6
# 7462      30  2017   8695             0  ...         9    0  78.5         1.5
# 7342      27  2019  24699             1  ...        10  145  44.1         1.5
# 8138      29  2017   9690             0  ...        10   20  60.1         1.2
# 8443      29  2019  19490             1  ...        10  145  39.8         2.0
# ...      ...   ...    ...           ...  ...       ...  ...   ...         ...
# 463       27  2015  17498             1  ...         8    0  76.4         2.1
# 12769     29  2019  10835             0  ...        10  145  54.3         1.0
# 1094      22  2017  11980             0  ...        10  145  52.3         1.0
# 2473      26  2019  29840             1  ...         9  145  60.1         2.0
# 7927      28  2017   9967             0  ...        10  145  47.1         1.4
#
# [19838 rows x 9 columns]

# %%
col_names=list(used_cars.columns[used_cars.columns!="price"])

# %%
col_names
# Out:
# ['model',
#  'year',
#  'transmission',
#  'mileage',
#  'fuelType',
#  'tax',
#  'mpg',
#  'engineSize']

# %%
scaler = StandardScaler()
scaled_data=scaler.fit_transform(x_train.loc[:,x_train.columns!="price"])

# %%
x_train[col_names]=scaled_data
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
scaler = StandardScaler()
scaled_data=scaler.fit_transform(x_test.loc[:,x_test.columns!="price"])

# %%
x_test[col_names]=scaled_data
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
x_train
# Out:
#           model      year  price  ...       tax       mpg  engineSize
# 6089  -0.401219 -1.461534  20572  ...  0.390047 -0.052463    0.605424
# 9696   1.265278  0.429550  14990  ...  0.390047 -0.114500   -1.190641
# 8769   0.848654 -0.043221   9950  ...  0.469453  0.307354   -0.831428
# 11240  1.265278  0.902321  18999  ...  0.390047 -1.287006   -0.292609
# 3721   0.432030 -1.934305   4798  ...  0.628264 -0.641818   -0.113002
# ...         ...       ...    ...  ...       ...       ...         ...
# 8464   0.848654 -0.043221   9990  ...  0.390047  0.307354   -0.831428
# 786    0.432030 -0.515992   7955  ... -1.436279 -0.052463   -0.472215
# 9760   1.265278 -0.515992   9990  ...  0.390047 -0.449502   -0.113002
# 2021  -1.651092 -0.043221   8350  ...  0.469453  0.307354   -0.831428
# 5999   1.265278  0.429550  16790  ...  0.390047 -0.592188   -0.292609
#
# [79348 rows x 9 columns]

# %%
x_test
# Out:
#           model      year  price  ...       tax       mpg  engineSize
# 1232  -1.645420  1.370802  19990  ...  0.395529 -0.058719   -0.115393
# 7462   1.268101 -0.033120   8695  ... -1.874647  1.433763   -0.293608
# 7342   0.019449  0.902828  24699  ...  0.395529 -0.687781   -0.293608
# 8138   0.851884 -0.033120   9690  ... -1.561519  0.298984   -0.828252
# 8443   0.851884  0.902828  19490  ...  0.395529 -0.952974    0.597466
# ...         ...       ...    ...  ...       ...       ...         ...
# 463    0.019449 -0.969068  17498  ... -1.874647  1.304250    0.775681
# 12769  0.851884  0.902828  10835  ...  0.395529 -0.058719   -1.184682
# 1094  -2.061638 -0.033120  11980  ...  0.395529 -0.182064   -1.184682
# 2473  -0.396768  0.902828  29840  ...  0.395529  0.298984    0.597466
# 7927   0.435667 -0.033120   9967  ...  0.395529 -0.502763   -0.471823
#
# [19838 rows x 9 columns]

# %% [markdown]
# ## Baseline for comparison...

# %%
start = time.time()
base_rbf=SVR(kernel='rbf').fit(x_train.loc[:,x_train.columns!="price"], x_train.loc[:,"price"])
end = time.time()
pred_rbf = base_rbf.predict(x_test.loc[:,x_train.columns!="price"])
# mean_absolute_error(y_true, y_pred)
# mean_squared_error(y_true, y_pred)
print("MAE: ",mean_absolute_error(x_test.loc[:,"price"], pred_rbf))
print("RMSE: ",math.sqrt(mean_squared_error(x_test.loc[:,"price"], pred_rbf)))
print("SCORE: ",base_rbf.score(x_test.loc[:,x_train.columns!="price"], x_test.loc[:,"price"]))
print(str("total time: ")+ (str(end - start)))
# Out:
# MAE:  4546.1795086486045
# RMSE:  7759.07111160152
# SCORE:  0.373140563279572
# total time: 505.6590197086334

# %%
start = time.time()
base_linear=SVR(kernel='linear').fit(x_train.loc[:,x_train.columns!="price"], x_train.loc[:,"price"])
end = time.time()
pred_linear = base_linear.predict(x_test.loc[:,x_train.columns!="price"])
# mean_absolute_error(y_true, y_pred)
# mean_squared_error(y_true, y_pred)
print("MAE: ",mean_absolute_error(x_test.loc[:,"price"], pred_linear))
print("RMSE: ",math.sqrt(mean_squared_error(x_test.loc[:,"price"], pred_linear)))
print("SCORE: ",base_linear.score(x_test.loc[:,x_train.columns!="price"], x_test.loc[:,"price"]))
print(str("total time: ")+ (str(end - start)))
# Out:
# MAE:  3384.776988766054
# RMSE:  5371.783481674125
# SCORE:  0.6995392807219364
# total time: 422.2041938304901

# %%
start = time.time()
base_poly=SVR(kernel='poly').fit(x_train.loc[:,x_train.columns!="price"], x_train.loc[:,"price"])
end = time.time()
pred_poly = base_poly.predict(x_test.loc[:,x_train.columns!="price"])
# mean_absolute_error(y_true, y_pred)
# mean_squared_error(y_true, y_pred)
print("MAE: ",mean_absolute_error(x_test.loc[:,"price"], pred_poly))
print("RMSE: ",math.sqrt(mean_squared_error(x_test.loc[:,"price"], pred_poly)))
print("SCORE: ",base_poly.score(x_test.loc[:,x_train.columns!="price"], x_test.loc[:,"price"]))
print(str("total time: ")+ (str(end - start)))
# Out:
# MAE:  4977.3527250557
# RMSE:  7474.7126610307205
# SCORE:  0.4182455573278425
# total time: 732.2479569911957

# %%
start = time.time()
base_sig=SVR(kernel='sigmoid').fit(x_train.loc[:,x_train.columns!="price"], x_train.loc[:,"price"])
end = time.time()
pred_sig = base_sig.predict(x_test.loc[:,x_train.columns!="price"])
# mean_absolute_error(y_true, y_pred)
# mean_squared_error(y_true, y_pred)
print("MAE: ",mean_absolute_error(x_test.loc[:,"price"], pred_sig))
print("RMSE: ",math.sqrt(mean_squared_error(x_test.loc[:,"price"], pred_sig)))
print("SCORE: ",base_sig.score(x_test.loc[:,x_train.columns!="price"], x_test.loc[:,"price"]))
print(str("total time: ")+ (str(end - start)))
# Out:
# MAE:  3802.4944887065253
# RMSE:  6464.753460336159
# SCORE:  0.5648343184226374
# total time: 590.9041473865509

# %% [markdown]
# ## SVR subsmple with Bayesian Optimization

# %%
svr_subsample_bayes_train(x_train,x_test,0.01,0.1,"price","rbf",5,0.70)
# Out:
# ####### BAYESIAN_OPT MODE #######
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    0.1s finished
# best score: 0.4572087772629428
# Interrupting!
# ++++++ TRAIN TIME (0) 0.15160202980041504 +++++++++++
# ####### BEST MODEL PARAMS INITIAL STEP (0) #####
# OrderedDict([('C', 288.2700717156663), ('degree', 4), ('epsilon', 4.856879063155949), ('kernel', 'rbf')])
# Coefficient of determination R^2 of the prediction:
#
# 0.5352593950547457
# MAE:  3639.6866922735926
# RMSE:  6680.822873726524
# ####### BEST MODEL PARAMS INITIAL STEP (0) #####
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.1s finished
# best score: 0.7120127293928444
# Interrupting!
# ...

# %%
svr_subsample_bayes_train(x_train,x_test,0.01,0.1,"price","linear",5,0.70)
# Out:
# ####### BAYESIAN_OPT MODE #######
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# best score: 0.6869625093243164
# Interrupting!
# ++++++ TRAIN TIME (0) 0.14037036895751953 +++++++++++
# ####### BEST MODEL PARAMS INITIAL STEP (0) #####
# OrderedDict([('C', 185.33086896874718), ('degree', 2), ('epsilon', 7.966851184220562), ('kernel', 'linear')])
# Coefficient of determination R^2 of the prediction:
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    0.1s finished
# 0.7136814973440919
# MAE:  3391.2147403150875
# RMSE:  5243.839072543667
# ####### BEST MODEL PARAMS INITIAL STEP (0) #####
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    5.0s finished
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# ...

# %%
svr_subsample_bayes_train(x_train,x_test,0.01,0.1,"price","sigmoid",5,0.70)
# Out:
# ####### BAYESIAN_OPT MODE #######
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# best score: -0.046873792606949724
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    0.1s finished
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    0.1s finished
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# best score: -0.046873792606949724
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# best score: -0.03496579352739203
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# best score: -0.03496579352739203
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    0.1s finished
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# ...

# %%
svr_subsample_bayes_train(x_train,x_test,0.01,0.1,"price","poly",5,0.70)
# Out:
# ####### BAYESIAN_OPT MODE #######
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# best score: -0.05307335953602353
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# best score: -0.05307335953602353
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    0.1s finished
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    0.1s finished
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    0.1s finished
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# best score: -0.05307335953602353
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# best score: -0.052431176174872515
# ...

# %% [markdown]
# ## Comparison without the subsample algorithm

# %%
import math
start = time.time()
Sv = BayesSearchCV(
    SVR(gamma='scale'),
    {
        'C': (1e-2, 1e+3,'log-uniform'),
        'degree': (2, 5),
        'epsilon': (1e-2, 1e+2,'log-uniform'),  # integer valued parameter
        'kernel': ['rbf']  # categorical parameter
    },
    cv=3,
    n_jobs=3,
    n_iter=10,
    verbose=3
)
# callback handler
def on_step(optim_result):
    score = Sv.best_score_
    print("best score: %s" % score)
    if score >= 0.60:
        print('Interrupting!')
        return True

Sv.fit(x_train.loc[:,x_train.columns!="price"], x_train.loc[:,"price"],callback=on_step)
end = time.time()
pred = Sv.predict(x_test.loc[:,x_train.columns!="price"])
# mean_absolute_error(y_true, y_pred)
# mean_squared_error(y_true, y_pred)
print("MAE: ",mean_absolute_error(x_test.loc[:,"price"], pred))
print("RMSE: ",math.sqrt(mean_squared_error(x_test.loc[:,"price"], pred)))
print("SCORE: ",Sv.score(x_test.loc[:,x_train.columns!="price"], x_test.loc[:,"price"]))
print(str("total time: ")+ (str(end - start)))
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  8.8min finished
# best score: 0.7355747112528818
# Interrupting!
# MAE:  2681.2352424452824
# RMSE:  4674.508577118284
# SCORE:  0.7726439772825355
# total time: 1001.78191447258

# %%
import math
start = time.time()
Sv = BayesSearchCV(
    SVR(gamma='scale'),
    {
        'C': (1e-2, 1e+3,'log-uniform'),
        'degree': (2, 5),
        'epsilon': (1e-2, 1e+2,'log-uniform'),  # integer valued parameter
        'kernel': ['linear']  # categorical parameter
    },
    cv=3,
    n_jobs=3,
    n_iter=10,
    verbose=3
)
# callback handler
def on_step(optim_result):
    score = Sv.best_score_
    print("best score: %s" % score)
    if score >= 0.60:
        print('Interrupting!')
        return True

Sv.fit(x_train.loc[:,x_train.columns!="price"], x_train.loc[:,"price"],callback=on_step)
end = time.time()
pred = Sv.predict(x_test.loc[:,x_train.columns!="price"])
# mean_absolute_error(y_true, y_pred)
# mean_squared_error(y_true, y_pred)
print("MAE: ",mean_absolute_error(x_test.loc[:,"price"], pred))
print("RMSE: ",math.sqrt(mean_squared_error(x_test.loc[:,"price"], pred)))
print("SCORE: ",Sv.score(x_test.loc[:,x_train.columns!="price"], x_test.loc[:,"price"]))
print(str("total time: ")+ (str(end - start)))
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  6.1min finished
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# best score: 0.5665036112217049
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  5.7min finished
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# best score: 0.5665036112217049
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  5.2min finished
# best score: 0.7011515401615195
# Interrupting!
# MAE:  3404.470063350454
# RMSE:  5394.733896061117
# SCORE:  0.6971869442253781
# total time: 1352.1349895000458

# %%
import math
start = time.time()
Sv = BayesSearchCV(
    SVR(gamma='scale'),
    {
        'C': (1e-2, 1e+3,'log-uniform'),
        'degree': (2, 5),
        'epsilon': (1e-2, 1e+2,'log-uniform'),  # integer valued parameter
        'kernel': ['poly']  # categorical parameter
    },
    cv=3,
    n_jobs=3,
    n_iter=10,
    verbose=3
)
# callback handler
def on_step(optim_result):
    score = Sv.best_score_
    print("best score: %s" % score)
    if score >= 0.50:
        print('Interrupting!')
        return True

Sv.fit(x_train.loc[:,x_train.columns!="price"], x_train.loc[:,"price"],callback=on_step)
end = time.time()
pred = Sv.predict(x_test.loc[:,x_train.columns!="price"])
# mean_absolute_error(y_true, y_pred)
# mean_squared_error(y_true, y_pred)
print("MAE: ",mean_absolute_error(x_test.loc[:,"price"], pred))
print("RMSE: ",math.sqrt(mean_squared_error(x_test.loc[:,"price"], pred)))
print("SCORE: ",Sv.score(x_test.loc[:,x_train.columns!="price"], x_test.loc[:,"price"]))
print(str("total time: ")+ (str(end - start)))
#27m 28 secs
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  6.5min finished
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# best score: -0.030719986357911462
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  6.8min finished
# best score: 0.6116528479442412
# Interrupting!
# MAE:  3694.9563074387097
# RMSE:  6750.166763726089

# %%
import math
start = time.time()
Sv = BayesSearchCV(
    SVR(gamma='scale'),
    {
        'C': (1e-2, 1e+3,'log-uniform'),
        'degree': (2, 5),
        'epsilon': (1e-2, 1e+2,'log-uniform'),  # integer valued parameter
        'kernel': ['sigmoid']  # categorical parameter
    },
    cv=3,
    n_jobs=3,
    n_iter=10,
    verbose=3
)
# callback handler
def on_step(optim_result):
    score = Sv.best_score_
    print("best score: %s" % score)
    if score >= 0.60:
        print('Interrupting!')
        return True

Sv.fit(x_train.loc[:,x_train.columns!="price"], x_train.loc[:,"price"],callback=on_step)
end = time.time()
pred = Sv.predict(x_test.loc[:,x_train.columns!="price"])
# mean_absolute_error(y_true, y_pred)
# mean_squared_error(y_true, y_pred)
print("MAE: ",mean_absolute_error(x_test.loc[:,"price"], pred))
print("RMSE: ",math.sqrt(mean_squared_error(x_test.loc[:,"price"], pred)))
print("SCORE: ",Sv.score(x_test.loc[:,x_train.columns!="price"], x_test.loc[:,"price"]))
print(str("total time: ")+ (str(end - start)))
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed: 19.4min finished
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# best score: 0.5565443627900503
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed: 15.2min finished
# best score: 0.6119561528959444
# Interrupting!
# MAE:  4060.166924112877
# RMSE:  6435.238467930544
# SCORE:  0.566956589908722
# total time: 2767.0439281463623
